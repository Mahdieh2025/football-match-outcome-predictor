# %% [markdown]
# # Bootcamp Final Project
# # End-to-End Football Data Analytics Pipeline
# ## Integrated Project for Module 1, Module 2, and Module 3
#
# ### Module 1 – Data Ingestion
#
# ### Objective
# The objective of this module is to ingest the raw football datasets from the source folders, validate their structure, and prepare them for downstream processing in the data pipeline.
#
# ### Input Data
# Raw data files stored in the following directories:
#
# data/raw/fivethirtyeight/
#
# data/raw/football_data/
#
# These folders contain the original, unprocessed datasets used in the project
#
# ### Output
# Structured and standardized datasets saved in Parquet format in:
#
# data/silver/
#
# Each season is stored as a separate Parquet file to enable efficient access and further preprocessing in subsequent modules.
#
# import pandas as pd
# import numpy as np

# %%
import os
os.getcwd()
import os
os.chdir(r"C:\Users\Public\Bootcamp_FinalProject\project_repo")
os.getcwd()
# Out:
# 'C:\\Users\\Public\\Bootcamp_FinalProject\\project_repo'

# %%
import pandas as pd
from pathlib import Path

base_path = Path("data/raw/football_data/mmz4281")

dfs = []

for season_folder in base_path.iterdir():
    csv_files = list(season_folder.glob("*.csv"))
    if csv_files:
        df_season = pd.read_csv(csv_files[0])
        df_season["season"] = season_folder.name
        dfs.append(df_season)

df = pd.concat(dfs, ignore_index=True)

df.shape
# Out:
# (3800, 153)

# %%
df.shape
df.columns
df.isnull().sum().head()
df.head()
# Out:
#    Div      Date    HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  ...  \
# 0  SP1  21/08/15      Malaga     Sevilla     0     0   D     0     0   D  ...
# 1  SP1  22/08/15  Ath Madrid  Las Palmas     1     0   H     1     0   H  ...
# 2  SP1  22/08/15     Espanol      Getafe     1     0   H     1     0   H  ...
# 3  SP1  22/08/15   La Coruna    Sociedad     0     0   D     0     0   D  ...
# 4  SP1  22/08/15   Vallecano    Valencia     0     0   D     0     0   D  ...
#
#    1XBCH  1XBCD  1XBCA  BFECH  BFECD  BFECA  BFEC>2.5  BFEC<2.5  BFECAHH  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN       NaN       NaN      NaN
# 1    NaN    NaN    NaN    NaN    NaN    NaN       NaN       NaN      NaN
# 2    NaN    NaN    NaN    NaN    NaN    NaN       NaN       NaN      NaN
# 3    NaN    NaN    NaN    NaN    NaN    NaN       NaN       NaN      NaN
# 4    NaN    NaN    NaN    NaN    NaN    NaN       NaN       NaN      NaN
#
#    BFECAHA
# 0      NaN
# 1      NaN
# 2      NaN
# ...
